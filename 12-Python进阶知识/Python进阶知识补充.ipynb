# %% [markdown]
# # Python和Numpy进阶知识补充

# %% [markdown]
# ## 变量、对象、引用

# %%
# 显示出对象的内存地址
class F(object):
    pass
f = F()
f

# %%
# 字符串是不可变对象
name = "Python"
name += "AI"

# %%
# cpython会对常用的整数对象进行缓存
print('case 1:')
a = 2
b = 2
print(a == b)
print(a is b)

print('\ncase 2:')
c = 20000
d = 20000
print(c == d)
print(c is d)
# Out:
# case 1:
# True
# True
#
# case 2:
# True
# False

# %%
# list1、list2[1]和dict1[‘list1’]都是同一个list对象的引用，并且由于list对象是可变对象，
# 通过上面三个变量中的任意一个变量修改该list对象都会影响到其余的变量

list1=[1,2,3,4]
list2=['hello',list1]
dict1={'list1':list1}

list1[0] = 0
print(list2)
print(dict1)
# Out:
# ['hello', [0, 2, 3, 4]]
# {'list1': [0, 2, 3, 4]}

# %%
# 赋值会使两个变量引用同一个变量
l1 = [1,2,3]
l2 = l1
l1[0] = 0
print(l1)
print(l2)
print(l1 == l2)
print(l1 is l2)
# Out:
# [0, 2, 3]
# [0, 2, 3]
# True
# True

# %%
# 更多和可变对象相关的例子
l1 = [1,2,3]
l3 = [1,2,3]
l1[0] = 0
print(l1)
print(l3)
# Out:
# [0, 2, 3]
# [1, 2, 3]

# %%
def f(x = [[]]):
    x[-1].append(3) 

x = (1, 2, [])

f(x)

print(x)
# Out:
# (1, 2, [3])

# %%
l1 = [1,2,3]
l3 = [1,2,3]
print(l1 == l3)
print(l1 is l3)
# Out:
# True
# False

# %%
old = [1, 2, 3, 4, 5]
new = old
old = [6]
print(old)
print(new)
# Out:
# [6]
# [1, 2, 3, 4, 5]

# %%
print(id(old))
print(id(new))
# Out:
# 4335858784
# 4335853392

# %%
# 一个标识与别名的例子
charles = {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 900}
lewis = charles
print(lewis is charles)
print(id(lewis), id(charles))
lewis['balance'] = 950
print(charles)
# Out:
# True
# 4335739360 4335739360
# {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}

# %%
# 冒充者
alex = {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}
print(lewis == alex)
print(alex is not lewis)
# Out:
# True
# True

# %%
# 元组是不可变对象，但是元组中的元素可以是可变对象
t1 = (1, 2, [30, 40])
t2 = (1, 2, [30, 40])
print(t1 == t2)
# Out:
# True

# %%
id(t1[-1])
# Out:
# 4335861184

# %%
t1[-1].append(1000)
print(t1)
print(t1 == t2)
print(id(t1[-1]))
# Out:
# (1, 2, [30, 40, 1000])
# False
# 4335861184

# %%
l1 = [3, [55, 44], (7, 8, 9)]
print(id(l1))
l2 = list(l1)
l3 = l1[:]
print(l2,id(l2))
print(l3,id(l3))
print(l1 == l2 == l3)
print(l2 is l1)
print(l3 is l1)
# Out:
# 1773855374528
# [3, [55, 44], (7, 8, 9)] 1773855424640
# [3, [55, 44], (7, 8, 9)] 1773855374144
# True
# False
# False

# %%
# 浅复制
from copy import copy
l4 = l1.copy()
print(id(l4))
print(l4 is l1)
print(id(l1[1]))
print(id(l4[1]))
# Out:
# 4335872432
# False
# 4299751232
# 4299751232

# %%
# 浅复制
from copy import copy, deepcopy

l1 = [3, [66, 55, 44], (7, 8, 9)]
l2 = copy(l1)    #浅复制了l1
l1.append(100)    #l1列表在尾部添加数值100
l1[1].remove(55)   #移除列表中第1个索引的值
print('l1:', l1)
print('l2:', l2)
l2[1] += [33, 22]   #l2列表中第1个索引做列表拼接
l2[2] += (10, 11)   #l2列表中的第2个索引做元祖拼接
print('l1:', l1)
print('l2:', l2)
# Out:
# l1: [3, [66, 44], (7, 8, 9), 100]
# l2: [3, [66, 44], (7, 8, 9)]
# l1: [3, [66, 44, 33, 22], (7, 8, 9), 100]
# l2: [3, [66, 44, 33, 22], (7, 8, 9, 10, 11)]

# %%
# 深复制
from copy import copy, deepcopy

l1 = [3, [66, 55, 44], (7, 8, 9)]
l2 = deepcopy(l1)    #深复制了l2
l1.append(100)    #l1列表在尾部添加数值100
l1[1].remove(55)   #移除列表中第1个索引的值
print('l1:', l1)
print('l2:', l2)
l2[1] += [33, 22]   #l2列表中第1个索引做列表拼接
l2[2] += (10, 11)   #l2列表中的第2个索引做元祖拼接
print('l1:', l1)
print('l2:', l2)
# Out:
# l1: [3, [66, 44], (7, 8, 9), 100]
# l2: [3, [66, 55, 44], (7, 8, 9)]
# l1: [3, [66, 44], (7, 8, 9), 100]
# l2: [3, [66, 55, 44, 33, 22], (7, 8, 9, 10, 11)]

# %%
# 对象的复制
class Bus: 
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)
 
    def pick(self, name):
        self.passengers.append(name)
 
    def drop(self, name):
        self.passengers.remove(name)

# %%
from copy import copy, deepcopy
 
bus1 = Bus(['Alice', 'Bill', 'Claire', 'David'])
bus2 = copy(bus1)      #bus2浅复制的bus1
bus3 = deepcopy(bus1)     #bus3深复制了bus1
print("=======================================")
print(id(bus1), id(bus2), id(bus3))  #查看三个对象的内存地址
print("=======================================") 
bus1.drop('Bill')      #bus1的车上Bill下车了
print('bus2:', bus2.passengers)   #bus2中的Bill也没有了！
print("=======================================")
print("bus1.pass=", id(bus1.passengers))
print("bus2.pass=", id(bus2.passengers))
print("bus3.pass=", id(bus3.passengers))
#, "bus2.pass=", id(bus2.passengers),"bus3.pass=" id(bus3.passengers)) 
#审查 passengers 属性后发现，bus1和bus2共享同一个列表对象，因为bus2是bus1的浅复制副本
 
print('bus3:', bus3.passengers)   
#bus3是bus1 的深复制副本，因此它的 passengers 属性指代另一个列表
# Out:
# =======================================
# 82759792 82760512 82759840
# =======================================
# bus2: ['Alice', 'Claire', 'David']
# =======================================
# bus1.pass= 82800576
# bus2.pass= 82800576
# bus3.pass= 80332416
# bus3: ['Alice', 'Bill', 'Claire', 'David']

# %%
# 一个递归引用的例子
# deepcopy能正确的处理
a = [10, 20]
b = [a, 30]
a.append(b)
print(a)

from copy import copy, deepcopy
c = deepcopy(a)
e = a.copy()
print(c[2][0][2][0][2][0][2][0][2])
print(e[2][0][2][0][2][0][2][0][2])
# Out:
# [10, 20, [[...], 30]]
# [[10, 20, [...]], 30]
# [[10, 20, [...]], 30]

# %%
# Python的参数传递模式是共享传参（call by sharing）
# 共享传参指函数的各个形式参数获得实参中各个引用的副本
def f(a, b):
    print("before, id(a)=", id(a))
    a += b############################################
    print("after, id(a)=", id(a))
    return a

x = 1
print("before the function call, id(x)= ", id(x))
y = 2
print(f(x, y))
print(x, y)

a = [1, 2]
b = [3, 4]
print(f(a, b))
print(a, b)

t = (10, 20)
u = (30, 40)
print(f(t, u))
print(t, u)
# Out:
# before the function call, id(x)=  8791486506784
# before, id(a)= 8791486506784
# after, id(a)= 8791486506848
# 3
# 1 2
# before, id(a)= 79839744
# after, id(a)= 79839744
# [1, 2, 3, 4]
# [1, 2, 3, 4] [3, 4]
# before, id(a)= 78841856
# after, id(a)= 79862256
# (10, 20, 30, 40)
# (10, 20) (30, 40)

# %%
# 危险的可变默认值
class HauntedBus:
    '''
     备受折磨的幽灵车
    ''' 
    def __init__(self, passengers=[]):
        self.passengers = passengers
 
    def pick(self, name):
        self.passengers.append(name)
 
    def drop(self, name):
        self.passengers.remove(name)
  
bus1 = HauntedBus(['Alice', 'Bill'])

print('bus1上的乘客：', bus1.passengers)
bus1.pick('Charlie')   #bus1上来一名乘客Charile
bus1.drop('Alice')    #bus1下去一名乘客Alice
print('bus1上的乘客：', bus1.passengers)   #打印bus1上的乘客
print("===============================")
bus2 = HauntedBus()    #实例化bus2
bus2.pick('Carrie')    #bus2上来一名乘客Carrie
print('bus2上的乘客：', bus2.passengers)
print("===============================")
bus3 = HauntedBus()
print('bus3上的乘客 (before picking)：', bus3.passengers)
bus3.pick('Dave')
print('bus3上的乘客 (after picking)：', bus3.passengers)
print('bus2上的乘客 ：', bus2.passengers)  
#登录到bus3上的乘客Dava跑到了bus2上面
print("===============================")
print('bus2是否为bus3的对象：', bus2.passengers is bus3.passengers)
print('bus1上的乘客：', bus1.passengers)
# Out:
# bus1上的乘客： ['Alice', 'Bill']
# bus1上的乘客： ['Bill', 'Charlie']
# ===============================
# bus2上的乘客： ['Carrie']
# ===============================
# bus3上的乘客 (before picking)： ['Carrie']
# bus3上的乘客 (after picking)： ['Carrie', 'Dave']
# bus2上的乘客 ： ['Carrie', 'Dave']
# ===============================
# bus2是否为bus3的对象： True
# bus1上的乘客： ['Bill', 'Charlie']

# %%
a = 3
