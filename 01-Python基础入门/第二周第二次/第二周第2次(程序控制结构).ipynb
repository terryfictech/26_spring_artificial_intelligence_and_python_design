# %% [markdown]
# # 第二周第2次
# ## 《工智能与Python程序设计》——程序的控制结构

# %%
import math as m 
r = float(input("圆半径："))
S = m.pi * r * r
L = m.pi * 2 * r

print("面积：{0}，周长：{1}".format(S, L))
# Out:
# 圆半径： 12
# 面积：452.3893421169302，周长：75.39822368615503

# %%
R = float(input("实数值："))
if R < 0:
    R = -R

print("绝对值：{0}".format(R))
# Out:
# 实数值： 12
# 绝对值：12.0

# %%
R = int(input("输入整数："))
i, S = 1, 0
while i <= R:
    S = S + i
    i = i + 1

print("1 + ... + {0} = {1}".format(R, S))
# Out:
# 输入整数： 10
# 1 + ... + 10 = 55

# %%
PM=int(input("请输入PM2.5数值:"))

if 0 <= PM and PM < 35:
    print("[1]")
    print("空气优质，快去户外运动!")
if 35 <= PM and PM <= 75:
    print("[2]")
    print("空气良好，适度户外活动！")
if 75 <= PM:
    print("[3]")
    print("空气污染，请小心！")
# Out:
# 请输入PM2.5数值: 123
# [3]
# 空气污染，请小心！

# %%
PM=int(input("请输入PM2.5数值:"))
if PM >= 75:
    print("空气存在污染，请小心！")
else:
    print("空气没有污染，可以开展户外运动!")

# %%
PM=int(input("请输入PM2.5数值:"))
y = (PM if PM >= 75 else 0)

print(y)
# Out:
# 请输入PM2.5数值:76
# 76

# %%
PM=int(input("请输入PM2.5数值:"))

print("空气存在污染，请小心！") if PM >= 75 else print("空气没有污染，可以开展户外运动!")
# Out:
# 请输入PM2.5数值:74
# 空气没有污染，可以开展户外运动!

# %%
PM=int(input("请输入PM2.5数值:"))
if PM < 35:
    print("空气优质，快去户外运动!")
elif PM <= 75:
    print("空气良好，适度户外活动！")
else:
    print("空气污染，请小心！")
# Out:
# 请输入PM2.5数值:76
# 空气污染，请小心！

# %%
height, weight = eval(input("请输入身高(米)和体重(公斤)[逗号隔开]:"))
print(height, weight)
bmi= weight / pow(height, 2)
print("BMI数值为：{:.2f}".format(bmi))


wto, dom = "", ""

if bmi < 18.5: #WTO标准
    wto="偏瘦"
elif bmi < 25: #18.5<=bmi<25
    wto="正常"
elif bmi < 30:#25<=bmi<30
    wto="偏胖"
else:
    wto="肥胖"
    
if bmi < 18.5:#我国卫生部标准
    dom="偏瘦"
elif bmi < 24:#18.5<=bmi<24
    dom="正常"
elif bmi < 28:#24<=bmi<28
    dom="偏胖"
else:
    dom="肥胖"

print("BMI指标为:国际'{0}',国内'{1}'".format(wto,dom))
# Out:
# 请输入身高(米)和体重(公斤)[逗号隔开]:1.75, 60
# 1.75 60
# BMI数值为：19.59
# BMI指标为:国际'正常',国内'正常'

# %%
number = 30
if number % 2 == 0:
    print(number, 'is even')
elif number % 3==0:
    print(number, 'is multiple of 3')
# Out:
# 30 is even

# %%
import math
a = float(input("Input a:"))
b = float(input("Input b:"))
c = float(input("Input c:"))

if a == 0:
    print("The equation is linear.")
else:
    delta = b**2 - 4 * a * c
    if delta < 0:
        print("No real root")
    elif delta == 0:
        print("One root:", -b/(2*a))
    else:
        root = math.sqrt(delta)
        s1 = (-b + root)/(2*a)
        s2 = (-b - root)/(2*a)
        print("Two roots:", s1, s2)
# Out:
# Input a:2, 1, 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d1cad652bb2a> in <module>
#       1 import math
# ----> 2 a = float(input("Input a:"))
#       3 b = float(input("Input b:"))
#       4 c = float(input("Input c:"))
#       5
#
# ValueError: could not convert string to float: '2, 1, 1'

# %%
num = eval(input("请输入一个整数"))


print(num)
print("-----------")

print(num ** 2)

print('hello world')
# Out:
# 请输入一个整数 afdafasd
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 num = eval(input("请输入一个整数"))
#       4 print(num)
#       5 print("-----------")
#
# File <string>:1
#
# NameError: name 'afdafasd' is not defined

# %%
try:
    x = eval(input("请输入一个整数"))
    print(x ** 2)
except:
    print("输入不是整数")
# Out:
# 请输入一个整数 fasdfasfdsa
# 输入不是整数

# %%
try:
    num = eval(input("请输入一个整数"))
    print(num ** 2)
except NameError:
    print("输入不是整数")

print('hello world')
# Out:
# 请输入一个整数a
# 输入不是整数
# hello world

# %%
try:
    x = eval(input("请输入一个整数"))
except NameError:
    print("输入不是整数")
else:
    print(x ** 2)
finally:
    print("done!")
# Out:
# 请输入一个整数 123c
# done!
# Traceback (most recent call last):
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[10], line 2
#     x = eval(input("请输入一个整数"))
#
#   File <string>:1
#     123c
#       ^
# SyntaxError: invalid decimal literal

# %%
R=int(input("请输入正整数:"))
s = 0
for i in range(R + 1):
    s = s + i

print("s = {0}".format(s))
# Out:
# 请输入正整数:100
# s = 5050

# %%
for c in "abcdefg":
    print(c)
# Out:
# a
# b
# c
# d
# e
# f
# g

# %%
R=int(input("请输入正整数:"))
s = 0
i = 0
while s < R:
    s = s + i
    i = i + 1

print("s = {0}, i = {1}".format(s, i))
# Out:
# 请输入正整数:100
# s = 105, i = 15

# %%
for s in "RUC":
    print(s, end = "")
    if s=="U":
        break
# Out:
# RU

# %%
for s in "RUC": 
    for i in range(10):
        print(s, end = "")
        if s=="I":
            break
# Out:
# RRRRRRRRRRUUUUUUUUUUCCCCCCCCCC

# %%
for s in "Python":
    if s=="t":
        break
    print(s, end = "")
print("\nEnd")
# Out:
# PyEnd

# %%
for s in "Python":
    if s=="o":
        continue
    print(s, end = "")
print("\nEnd")
# Out:
# Pythn
# End

# %%
import random
random.seed()
print(random.random())
print(random.random())
print(random.random())
print(random.random())
# Out:
# 0.5714025946899135
# 0.4288890546751146
# 0.5780913011344704
# 0.20609823213950174

# %%
import random
import math

N=100000000
hits=0.0

random.seed()

for i in range(1, N+1):
    x,y = random.random(),random.random()
    dist = math.sqrt(x**2+y**2)
    if dist<=1.0:
        hits = hits + 1

pi= 4 * (hits / N)
print("Pi={0}.".format(pi))
# Out:
# Pi=3.14150884.
